# %% [markdown]
# ## Main.py
#
# We use main.py to do the ingestion of our data from the API and save it into data/raw as a .json file with a timestamp on it.
#
#
#
# ## transform.py   (START STAGE)
#
# we are going to transform our data from raw to stg
#
# Created a file inside /src called transform.py that basically extract key fields and build a structure dataset. Fields that we care about:
#
# id
# symbol
# name
# current_price
# market_cap
# total_volume
# price_change_percentage_24hs
# market_cap_change_percentage_24hs
# last_updated = "timestamp"
#
#
# we are going to create a DF with pandas, save all the .json info there and then, with that pandas df, create a file.csv into our path /stg.
#
# so first error handling ( raise an exeption if the raw files doesnt exists)
#
# then load json from that raw_files and create the variable data with all the json load inside
#
# convert json into pandas df = pd.DataFrame(data)
#
# then select which columns do we want from that pd dataframe, by creating a list columns_wanted[]
#
# then we save all the data into df_stg from df.
#
# final step is to standardie name and save stg.
#
# at the last step we ensure that STG folder exists and transfor the df_stg to csv.
